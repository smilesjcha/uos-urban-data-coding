# %% [markdown]
# # Getting Started with pandas

# %%
import pandas as pd

# %%
from pandas import Series, DataFrame

# %%
import numpy as np
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## Introduction to pandas Data Structures

# %% [markdown]
# ### Series

# %%
obj = pd.Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj.values
obj.index  # like range(4)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2['a']
obj2['d'] = 6
obj2[['c', 'a', 'd']]
# Out:
# c    3
# a   -5
# d    6
# dtype: int64

# %%
obj2[obj2 > 0]
obj2 * 2
np.exp(obj2)
# Out:
# d     403.428793
# b    1096.633158
# a       0.006738
# c      20.085537
# dtype: float64

# %%
'b' in obj2
'e' in obj2
# Out:
# False

# %%
sdata = {'Ohio': 35000, 'Texas': 71000, 'Oregon': 16000, 'Utah': 5000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
states = ['California', 'Ohio', 'Oregon', 'Texas']
obj4 = pd.Series(sdata, index=states)
obj4
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64

# %%
pd.isnull(obj4)
pd.notnull(obj4)
# Out:
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool

# %%
obj4.isnull()
# Out:
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
obj3
obj4
obj3 + obj4
# Out:
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64

# %%
obj4.name = 'population'
obj4.index.name = 'state'
obj4
# Out:
# state
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# Name: population, dtype: float64

# %%
obj
obj.index = ['Bob', 'Steve', 'Jeff', 'Ryan']
obj
# Out:
# Bob      4
# Steve    7
# Jeff    -5
# Ryan     3
# dtype: int64

# %% [markdown]
# ### DataFrame

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
        'year': [2000, 2001, 2002, 2001, 2002, 2003],
        'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
pd.DataFrame(data, columns=['year', 'state', 'pop'])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
                      index=['one', 'two', 'three', 'four',
                             'five', 'six'])
frame2
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2['state']
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame2.state
# Out:
# one        Ohio
# two        Ohio
# three      Ohio
# four     Nevada
# five     Nevada
# six      Nevada
# Name: state, dtype: object

# %%
frame2['pop']
# Out:
# one      1.5
# two      1.7
# three    3.6
# four     2.4
# five     2.9
# six      3.2
# Name: pop, dtype: float64

# %%
frame2.pop
# Out:
# <bound method DataFrame.pop of        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN>

# %%
frame2.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2001
# five     2002
# six      2003
# Name: year, dtype: int64

# %%
frame2.loc['three']
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: three, dtype: object

# %%
frame2['debt'] = 16.5
frame2
frame2['debt'] = np.arange(6.)
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   0.0
# two    2001    Ohio  1.7   1.0
# three  2002    Ohio  3.6   2.0
# four   2001  Nevada  2.4   3.0
# five   2002  Nevada  2.9   4.0
# six    2003  Nevada  3.2   5.0

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=['two', 'four', 'five'])
frame2['debt'] = val
frame2
# Out:
#        year   state  pop  debt
# one    2000    Ohio  1.5   NaN
# two    2001    Ohio  1.7  -1.2
# three  2002    Ohio  3.6   NaN
# four   2001  Nevada  2.4  -1.5
# five   2002  Nevada  2.9  -1.7
# six    2003  Nevada  3.2   NaN

# %%
frame2['eastern'] = frame2.state == 'Ohio'
frame2
# Out:
#        year   state  pop  debt  eastern
# one    2000    Ohio  1.5   NaN     True
# two    2001    Ohio  1.7  -1.2     True
# three  2002    Ohio  3.6   NaN     True
# four   2001  Nevada  2.4  -1.5    False
# five   2002  Nevada  2.9  -1.7    False
# six    2003  Nevada  3.2   NaN    False

# %%
del frame2['eastern']
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
pop = {'Nevada': {2001: 2.4, 2002: 2.9},
       'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}

# %%
frame3 = pd.DataFrame(pop)
frame3
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2000     NaN   1.5

# %%
frame3.T
# Out:
#         2001  2002  2000
# Nevada   2.4   2.9   NaN
# Ohio     1.7   3.6   1.5

# %%
pd.DataFrame(pop, index=[2001, 2002, 2003])
# Out:
#       Nevada  Ohio
# 2001     2.4   1.7
# 2002     2.9   3.6
# 2003     NaN   NaN

# %%
pdata = {'Ohio': frame3['Ohio'][:-1],
         'Nevada': frame3['Nevada'][:2]}
pd.DataFrame(pdata)
# Out:
#       Ohio  Nevada
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
frame3.index.name = 'year'; frame3.columns.name = 'state'
frame3
# Out:
# state  Nevada  Ohio
# year
# 2001      2.4   1.7
# 2002      2.9   3.6
# 2000      NaN   1.5

# %%
frame3.values
# Out:
# array([[2.4, 1.7],
#        [2.9, 3.6],
#        [nan, 1.5]])

# %%
frame2.values
# Out:
# array([[2000, 'Ohio', 1.5, nan],
#        [2001, 'Ohio', 1.7, -1.2],
#        [2002, 'Ohio', 3.6, nan],
#        [2001, 'Nevada', 2.4, -1.5],
#        [2002, 'Nevada', 2.9, -1.7],
#        [2003, 'Nevada', 3.2, nan]], dtype=object)

# %% [markdown]
# ### Index Objects

# %%
obj = pd.Series(range(3), index=['a', 'b', 'c'])
index = obj.index
index
index[1:]
# Out:
# Index(['b', 'c'], dtype='object')

# %% [markdown]
# index[1] = 'd'  # TypeError

# %%
labels = pd.Index(np.arange(3))
labels
obj2 = pd.Series([1.5, -2.5, 0], index=labels)
obj2
obj2.index is labels
# Out:
# True

# %%
frame3
frame3.columns
'Ohio' in frame3.columns
2003 in frame3.index
# Out:
# False

# %%
dup_labels = pd.Index(['foo', 'foo', 'bar', 'bar'])
dup_labels
# Out:
# Index(['foo', 'foo', 'bar', 'bar'], dtype='object')

# %% [markdown]
# ## Essential Functionality

# %% [markdown]
# ### Reindexing

# %%
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=['d', 'b', 'a', 'c'])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
obj2 = obj.reindex(['a', 'b', 'c', 'd', 'e'])
obj2
# Out:
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0, 2, 4])
obj3
obj3.reindex(range(6), method='ffill')
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),
                     index=['a', 'c', 'd'],
                     columns=['Ohio', 'Texas', 'California'])
frame
frame2 = frame.reindex(['a', 'b', 'c', 'd'])
frame2
# Out:
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
states = ['Texas', 'Utah', 'California']
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %%
frame2.loc[['a', 'b', 'c', 'd'], states]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-854455687.py in <cell line: 0>()
# ----> 1 frame2.loc[['a', 'b', 'c', 'd'], states]
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1182             if self._is_scalar_access(key):
#    1183                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184             return self._getitem_tuple(key)
#    1185         else:
#    1186             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1373         # ugly hack for GH #836
#    1374         if self._multi_take_opportunity(tup):
# -> 1375             return self._multi_take(tup)
#    1376
#    1377         return self._getitem_tuple_same_dim(tup)
#
# ...

# %% [markdown]
# ### Dropping Entries from an Axis

# %%
obj = pd.Series(np.arange(5.), index=['a', 'b', 'c', 'd', 'e'])
obj
new_obj = obj.drop('c')
new_obj
obj.drop(['d', 'c'])
# Out:
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop(['Colorado', 'Ohio'])
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data.drop('two', axis=1)
data.drop(['two', 'four'], axis='columns')
# Out:
#           one  three
# Ohio        0      2
# Colorado    4      6
# Utah        8     10
# New York   12     14

# %%
obj.drop('c', inplace=True)
obj
# Out:
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64

# %% [markdown]
# ### Indexing, Selection, and Filtering

# %%
obj = pd.Series(np.arange(4.), index=['a', 'b', 'c', 'd'])
obj
obj['b']
obj[1]
obj[2:4]
obj[['b', 'a', 'd']]
obj[[1, 3]]
obj[obj < 2]
# Out:
# /tmp/ipython-input-2795102731.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[1]
# /tmp/ipython-input-2795102731.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   obj[[1, 3]]
# a    0.0
# b    1.0
# dtype: float64

# %%
obj['b':'c']
# Out:
# b    1.0
# c    2.0
# dtype: float64

# %%
obj['b':'c'] = 5
obj
# Out:
# a    0.0
# b    5.0
# c    5.0
# d    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=['Ohio', 'Colorado', 'Utah', 'New York'],
                    columns=['one', 'two', 'three', 'four'])
data
data['two']
data[['three', 'one']]
# Out:
#           three  one
# Ohio          2    0
# Colorado      6    4
# Utah         10    8
# New York     14   12

# %%
data[:2]
data[data['three'] > 5]
# Out:
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
data < 5
data[data < 5] = 0
data
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %% [markdown]
# #### Selection with loc and iloc

# %%
data.loc['Colorado', ['two', 'three']]
# Out:
# two      5
# three    6
# Name: Colorado, dtype: int64

# %%
data.iloc[2, [3, 0, 1]]
data.iloc[2]
data.iloc[[1, 2], [3, 0, 1]]
# Out:
#           four  one  two
# Colorado     7    0    5
# Utah        11    8    9

# %%
data.loc[:'Utah', 'two']
data.iloc[:, :3][data.three > 5]
# Out:
#           one  two  three
# Colorado    0    5      6
# Utah        8    9     10
# New York   12   13     14

# %% [markdown]
# ### Integer Indexes

# %% [markdown]
# ser = pd.Series(np.arange(3.))
# ser
# ser[-1]

# %%
ser = pd.Series(np.arange(3.))

# %%
ser
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# dtype: float64

# %%
ser2 = pd.Series(np.arange(3.), index=['a', 'b', 'c'])
ser2[-1]
# Out:
# /tmp/ipython-input-2842014175.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ser2[-1]
# np.float64(2.0)

# %%
ser[:1]
ser.loc[:1]
ser.iloc[:1]
# Out:
# 0    0.0
# dtype: float64

# %% [markdown]
# ### Arithmetic and Data Alignment

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=['a', 'c', 'd', 'e'])
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1],
               index=['a', 'c', 'e', 'f', 'g'])
s1
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
s1 + s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list('bcd'),
                   index=['Ohio', 'Texas', 'Colorado'])
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'),
                   index=['Utah', 'Ohio', 'Texas', 'Oregon'])
df1
df2
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
df1 + df2
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %%
df1 = pd.DataFrame({'A': [1, 2]})
df2 = pd.DataFrame({'B': [3, 4]})
df1
df2
df1 - df2
# Out:
#     A   B
# 0 NaN NaN
# 1 NaN NaN

# %% [markdown]
# #### Arithmetic methods with fill values

# %%
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)),
                   columns=list('abcd'))
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)),
                   columns=list('abcde'))
df2.loc[1, 'b'] = np.nan
df1
df2
# Out:
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   NaN   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
df1 + df2
# Out:
#       a     b     c     d   e
# 0   0.0   2.0   4.0   6.0 NaN
# 1   9.0   NaN  13.0  15.0 NaN
# 2  18.0  20.0  22.0  24.0 NaN
# 3   NaN   NaN   NaN   NaN NaN

# %%
df1.add(df2, fill_value=0)
# Out:
#       a     b     c     d     e
# 0   0.0   2.0   4.0   6.0   4.0
# 1   9.0   5.0  13.0  15.0   9.0
# 2  18.0  20.0  22.0  24.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
1 / df1
df1.rdiv(1)
# Out:
#        a         b         c         d
# 0    inf  1.000000  0.500000  0.333333
# 1  0.250  0.200000  0.166667  0.142857
# 2  0.125  0.111111  0.100000  0.090909

# %%
df1.reindex(columns=df2.columns, fill_value=0)
# Out:
#      a    b     c     d  e
# 0  0.0  1.0   2.0   3.0  0
# 1  4.0  5.0   6.0   7.0  0
# 2  8.0  9.0  10.0  11.0  0

# %% [markdown]
# #### Operations between DataFrame and Series

# %%
arr = np.arange(12.).reshape((3, 4))
arr
arr[0]
arr - arr[0]
# Out:
# array([[0., 0., 0., 0.],
#        [4., 4., 4., 4.],
#        [8., 8., 8., 8.]])

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
                     columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
series = frame.iloc[0]
frame
series
# Out:
# b    0.0
# d    1.0
# e    2.0
# Name: Utah, dtype: float64

# %%
frame - series
# Out:
#           b    d    e
# Utah    0.0  0.0  0.0
# Ohio    3.0  3.0  3.0
# Texas   6.0  6.0  6.0
# Oregon  9.0  9.0  9.0

# %%
series2 = pd.Series(range(3), index=['b', 'e', 'f'])
frame + series2
# Out:
#           b   d     e   f
# Utah    0.0 NaN   3.0 NaN
# Ohio    3.0 NaN   6.0 NaN
# Texas   6.0 NaN   9.0 NaN
# Oregon  9.0 NaN  12.0 NaN

# %%
series3 = frame['d']
frame
series3
frame.sub(series3, axis='index')
# Out:
#           b    d    e
# Utah   -1.0  0.0  1.0
# Ohio   -1.0  0.0  1.0
# Texas  -1.0  0.0  1.0
# Oregon -1.0  0.0  1.0

# %% [markdown]
# ### Function Application and Mapping

# %%
frame = pd.DataFrame(np.random.randn(4, 3), columns=list('bde'),
                     index=['Utah', 'Ohio', 'Texas', 'Oregon'])
frame
np.abs(frame)
# Out:
#                b         d         e
# Utah    0.204708  0.478943  0.519439
# Ohio    0.555730  1.965781  1.393406
# Texas   0.092908  0.281746  0.769023
# Oregon  1.246435  1.007189  1.296221

# %%
f = lambda x: x.max() - x.min()
frame.apply(f)
# Out:
# b    1.802165
# d    1.684034
# e    2.689627
# dtype: float64

# %%
frame.apply(f, axis='columns')
# Out:
# Utah      0.998382
# Ohio      2.521511
# Texas     0.676115
# Oregon    2.542656
# dtype: float64

# %%
def f(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])
frame.apply(f)
# Out:
#             b         d         e
# min -0.555730  0.281746 -1.296221
# max  1.246435  1.965781  1.393406

# %%
format = lambda x: '%.2f' % x
frame.applymap(format)
# Out:
# /tmp/ipython-input-1073433956.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   frame.applymap(format)
#             b     d      e
# Utah    -0.20  0.48  -0.52
# Ohio    -0.56  1.97   1.39
# Texas    0.09  0.28   0.77
# Oregon   1.25  1.01  -1.30

# %%
frame['e'].map(format)
# Out:
# Utah      -0.52
# Ohio       1.39
# Texas      0.77
# Oregon    -1.30
# Name: e, dtype: object

# %% [markdown]
# ### Sorting and Ranking

# %%
obj = pd.Series(range(4), index=['d', 'a', 'b', 'c'])
obj.sort_index()
# Out:
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
                     index=['three', 'one'],
                     columns=['d', 'a', 'b', 'c'])
frame.sort_index()
frame.sort_index(axis=1)
# Out:
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4

# %%
frame.sort_index(axis=1, ascending=False)
# Out:
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5

# %%
obj = pd.Series([4, 7, -3, 2])
obj.sort_values()
# Out:
# 2   -3
# 3    2
# 0    4
# 1    7
# dtype: int64

# %%
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj.sort_values()
# Out:
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# 1    NaN
# 3    NaN
# dtype: float64

# %%
frame = pd.DataFrame({'b': [4, 7, -3, 2], 'a': [0, 1, 0, 1]})
frame
frame.sort_values(by='b')
# Out:
#    b  a
# 2 -3  0
# 3  2  1
# 0  4  0
# 1  7  1

# %%
frame.sort_values(by=['a', 'b'])
# Out:
#    b  a
# 2 -3  0
# 0  4  0
# 3  2  1
# 1  7  1

# %%
obj = pd.Series([7, -5, 7, 4, 2, 0, 4])
obj.rank()
# Out:
# 0    6.5
# 1    1.0
# 2    6.5
# 3    4.5
# 4    3.0
# 5    2.0
# 6    4.5
# dtype: float64

# %%
obj.rank(method='first')
# Out:
# 0    6.0
# 1    1.0
# 2    7.0
# 3    4.0
# 4    3.0
# 5    2.0
# 6    5.0
# dtype: float64

# %%
# Assign tie values the maximum rank in the group
obj.rank(ascending=False, method='max')
# Out:
# 0    2.0
# 1    7.0
# 2    2.0
# 3    4.0
# 4    5.0
# 5    6.0
# 6    4.0
# dtype: float64

# %%
frame = pd.DataFrame({'b': [4.3, 7, -3, 2], 'a': [0, 1, 0, 1],
                      'c': [-2, 5, 8, -2.5]})
frame
frame.rank(axis='columns')
# Out:
#      b    a    c
# 0  3.0  2.0  1.0
# 1  3.0  1.0  2.0
# 2  1.0  2.0  3.0
# 3  3.0  2.0  1.0

# %% [markdown]
# ### Axis Indexes with Duplicate Labels

# %%
obj = pd.Series(range(5), index=['a', 'a', 'b', 'b', 'c'])
obj
# Out:
# a    0
# a    1
# b    2
# b    3
# c    4
# dtype: int64

# %%
obj.index.is_unique
# Out:
# False

# %%
obj['a']
obj['c']
# Out:
# np.int64(4)

# %%
df = pd.DataFrame(np.random.randn(4, 3), index=['a', 'a', 'b', 'b'])
df
df.loc['b']
# Out:
#           0         1         2
# b  1.669025 -0.438570 -0.539741
# b  0.476985  3.248944 -1.021228

# %% [markdown]
# ## Summarizing and Computing Descriptive Statistics

# %%
df = pd.DataFrame([[1.4, np.nan], [7.1, -4.5],
                   [np.nan, np.nan], [0.75, -1.3]],
                  index=['a', 'b', 'c', 'd'],
                  columns=['one', 'two'])
df
# Out:
#     one  two
# a  1.40  NaN
# b  7.10 -4.5
# c   NaN  NaN
# d  0.75 -1.3

# %%
df.sum()
# Out:
# one    9.25
# two   -5.80
# dtype: float64

# %%
df.sum(axis='columns')
# Out:
# a    1.40
# b    2.60
# c    0.00
# d   -0.55
# dtype: float64

# %%
df.mean(axis='columns', skipna=False)
# Out:
# a      NaN
# b    1.300
# c      NaN
# d   -0.275
# dtype: float64

# %%
df.idxmax()
# Out:
# one    b
# two    d
# dtype: object

# %%
df.cumsum()
# Out:
#     one  two
# a  1.40  NaN
# b  8.50 -4.5
# c   NaN  NaN
# d  9.25 -5.8

# %%
df.describe()
# Out:
#             one       two
# count  3.000000  2.000000
# mean   3.083333 -2.900000
# std    3.493685  2.262742
# min    0.750000 -4.500000
# 25%    1.075000 -3.700000
# 50%    1.400000 -2.900000
# 75%    4.250000 -2.100000
# max    7.100000 -1.300000

# %%
obj = pd.Series(['a', 'a', 'b', 'c'] * 4)
obj.describe()
# Out:
# count     16
# unique     3
# top        a
# freq       8
# dtype: object

# %%
import pandas as pd
import numpy as np

# 숫자형과 범주형 변수가 공존하는 DataFrame 생성
data = {
    'numerical_col_1': [1, 2, 3, 4, 5, 6],
    'numerical_col_2': [10.5, 20.1, 30.0, 40.8, 50.3, 60.7],
    'categorical_col_1': ['A', 'B', 'A', 'C', 'B', 'A'],
    'categorical_col_2': ['apple', 'banana', 'orange', 'apple', 'banana', 'orange']
}
df_mixed = pd.DataFrame(data)

print("생성된 DataFrame:")
display(df_mixed)

print("\nDataFrame의 describe() 결과 (모든 컬럼 포함):")
display(df_mixed.describe(include='all'))
# Out:
# 생성된 DataFrame:
#    numerical_col_1  numerical_col_2 categorical_col_1 categorical_col_2
# 0                1             10.5                 A             apple
# 1                2             20.1                 B            banana
# 2                3             30.0                 A            orange
# 3                4             40.8                 C             apple
# 4                5             50.3                 B            banana
# 5                6             60.7                 A            orange
# DataFrame의 describe() 결과 (모든 컬럼 포함):
#         numerical_col_1  numerical_col_2 categorical_col_1 categorical_col_2
# count          6.000000         6.000000                 6                 6
# unique              NaN              NaN                 3                 3
# top                 NaN              NaN                 A             apple
# freq                NaN              NaN                 3                 2
# ...

# %%
df_mixed.describe()
# Out:
#        numerical_col_1  numerical_col_2
# count         6.000000         6.000000
# mean          3.500000        35.400000
# std           1.870829        18.838896
# min           1.000000        10.500000
# 25%           2.250000        22.575000
# 50%           3.500000        35.400000
# 75%           4.750000        47.925000
# max           6.000000        60.700000

# %%
import pandas as pd

data = {'numerical_col': [1, 2, 3, 4, 5],
        'string_col': ['a', 'b', 'c', 'd', 'e']}
df_mixed = pd.DataFrame(data)
display(df_mixed.describe(include="all"))
# Out:
#         numerical_col string_col
# count        5.000000          5
# unique            NaN          5
# top               NaN          a
# freq              NaN          1
# mean         3.000000        NaN
# std          1.581139        NaN
# min          1.000000        NaN
# 25%          2.000000        NaN
# 50%          3.000000        NaN
# 75%          4.000000        NaN
# max          5.000000        NaN

# %% [markdown]
# ### Correlation and Covariance

# %% [markdown]
# conda install pandas-datareader

# %%
price = pd.read_pickle('yahoo_price.pkl')
volume = pd.read_pickle('yahoo_volume.pkl')

# %% [markdown]
# import pandas_datareader.data as web
# all_data = {ticker: web.get_data_yahoo(ticker)
#             for ticker in ['AAPL', 'IBM', 'MSFT', 'GOOG']}
#
# price = pd.DataFrame({ticker: data['Adj Close']
#                      for ticker, data in all_data.items()})
# volume = pd.DataFrame({ticker: data['Volume']
#                       for ticker, data in all_data.items()})

# %%
returns = price.pct_change()
returns.tail()
# Out:
#                 AAPL      GOOG       IBM      MSFT
# Date
# 2016-10-17 -0.000680  0.001837  0.002072 -0.003483
# 2016-10-18 -0.000681  0.019616 -0.026168  0.007690
# 2016-10-19 -0.002979  0.007846  0.003583 -0.002255
# 2016-10-20 -0.000512 -0.005652  0.001719 -0.004867
# 2016-10-21 -0.003930  0.003011 -0.012474  0.042096

# %%
returns['MSFT'].corr(returns['IBM'])
returns['MSFT'].cov(returns['IBM'])
# Out:
# np.float64(8.870655479703546e-05)

# %%
returns.MSFT.corr(returns.IBM)
# Out:
# np.float64(0.49976361144151144)

# %%
returns.corr()
returns.cov()
# Out:
#           AAPL      GOOG       IBM      MSFT
# AAPL  0.000277  0.000107  0.000078  0.000095
# GOOG  0.000107  0.000251  0.000078  0.000108
# IBM   0.000078  0.000078  0.000146  0.000089
# MSFT  0.000095  0.000108  0.000089  0.000215

# %%
returns.corrwith(returns.IBM)
# Out:
# AAPL    0.386817
# GOOG    0.405099
# IBM     1.000000
# MSFT    0.499764
# dtype: float64

# %%
returns.corrwith(volume)
# Out:
# AAPL   -0.075565
# GOOG   -0.007067
# IBM    -0.204849
# MSFT   -0.092950
# dtype: float64

# %% [markdown]
# ### Unique Values, Value Counts, and Membership

# %%
obj = pd.Series(['c', 'a', 'd', 'a', 'a', 'b', 'b', 'c', 'c'])

# %%
uniques = obj.unique()
uniques
# Out:
# array(['c', 'a', 'd', 'b'], dtype=object)

# %%
obj.value_counts()
# Out:
# c    3
# a    3
# b    2
# d    1
# Name: count, dtype: int64

# %%
pd.value_counts(obj.values, sort=False)
# Out:
# /tmp/ipython-input-3084372382.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(obj.values, sort=False)
# c    3
# a    3
# d    1
# b    2
# Name: count, dtype: int64

# %%
obj
mask = obj.isin(['b', 'c'])
mask
obj[mask]
# Out:
# 0    c
# 5    b
# 6    b
# 7    c
# 8    c
# dtype: object

# %%
to_match = pd.Series(['c', 'a', 'b', 'b', 'c', 'a'])
unique_vals = pd.Series(['c', 'b', 'a'])
pd.Index(unique_vals).get_indexer(to_match)
# Out:
# array([0, 2, 1, 1, 0, 2])

# %%
data = pd.DataFrame({'Qu1': [1, 3, 4, 3, 4],
                     'Qu2': [2, 3, 1, 2, 3],
                     'Qu3': [1, 5, 2, 4, 4]})
data
# Out:
#    Qu1  Qu2  Qu3
# 0    1    2    1
# 1    3    3    5
# 2    4    1    2
# 3    3    2    4
# 4    4    3    4

# %%
result = data.apply(pd.value_counts).fillna(0)
result
# Out:
# /tmp/ipython-input-1382616601.py:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   result = data.apply(pd.value_counts).fillna(0)
#    Qu1  Qu2  Qu3
# 1  1.0  1.0  1.0
# 2  0.0  2.0  1.0
# 3  2.0  2.0  0.0
# 4  2.0  0.0  2.0
# 5  0.0  0.0  1.0

# %% [markdown]
# ## Conclusion

# %%
pd.options.display.max_rows = PREVIOUS_MAX_ROWS

# %%
# Example Series of fruits with duplicates
fruits = pd.Series(['apple', 'banana', 'apple', 'orange', 'banana', 'apple'])

# Count the occurrences of each fruit
fruit_counts = fruits.value_counts()

# Display the result
display(fruit_counts)
# Out:
# apple     3
# banana    2
# orange    1
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

# Example DataFrame
df = pd.DataFrame({
    'col1': [1, 2, 3, 4],
    'col2': [10, 20, 30, 40],
    'col3': ['apple', 'banana', 'cherry', 'date']
})

print("Original DataFrame:")
display(df)

# --- apply() examples ---
# Apply a function to each column (default axis=0)
print("\nApplying a function to each column (sum):")
display(df[['col1', 'col2']].apply(sum))

# Apply a function to each row (axis=1)
print("\nApplying a function to each row (sum of numerical columns):")
display(df[['col1', 'col2']].apply(sum, axis=1))

# Apply a function that returns a Series
print("\nApplying a function that returns a Series (min/max of numerical columns):")
def min_max(x):
    return pd.Series([x.min(), x.max()], index=['min', 'max'])
display(df[['col1', 'col2']].apply(min_max))

# --- map() examples (for Series) ---
# Map values in a Series using a dictionary
print("\nMapping values in a Series using a dictionary:")
status_map = {'apple': 'fruit', 'banana': 'fruit', 'cherry': 'fruit', 'date': 'fruit'}
display(df['col3'].map(status_map))

# Map values in a Series using a function
print("\nMapping values in a Series using a function (uppercase):")
display(df['col3'].map(lambda x: x.upper()))


# --- applymap() / map() examples (for DataFrames) ---
# applymap is deprecated, use map for element-wise operations on DataFrames
print("\nApplying a function element-wise to the DataFrame (using map):")
display(df[['col1', 'col2']].map(lambda x: x * 2))

# Applying format to specific columns
print("\nApplying format to specific columns using applymap (deprecated) or map:")
# Using applymap (deprecated)
# display(df[['col1', 'col2']].applymap(lambda x: f'${x:.2f}'))

# Using map (recommended for element-wise)
display(df[['col1', 'col2']].map(lambda x: f'${x:.2f}'))
# Out:
# Original DataFrame:
#    col1  col2    col3
# 0     1    10   apple
# 1     2    20  banana
# 2     3    30  cherry
# 3     4    40    date
# Applying a function to each column (sum):
# col1     10
# col2    100
# dtype: int64
# Applying a function to each row (sum of numerical columns):
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64
# Applying a function that returns a Series (min/max of numerical columns):
#      col1  col2
# min     1    10
# max     4    40
# Mapping values in a Series using a dictionary:
# 0    fruit
# 1    fruit
# 2    fruit
# 3    fruit
# Name: col3, dtype: object
# Mapping values in a Series using a function (uppercase):
# 0     APPLE
# 1    BANANA
# 2    CHERRY
# 3      DATE
# Name: col3, dtype: object
# Applying a function element-wise to the DataFrame (using map):
#    col1  col2
# 0     2    20
# 1     4    40
# 2     6    60
# 3     8    80
# Applying format to specific columns using applymap (deprecated) or map:
#     col1    col2
# ...
